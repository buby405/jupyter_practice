# %% [markdown]
# ## 数式の表示
#
# このコードセルでは、次のように数式を表現できます。
#
# \begin{align}
# \sqrt{2x-1} + (3+x)^3
# \end{align}
#
# $$E = mc^2$$
#
# インラインでも右記のように$\sqrt{a^2 + b^2}$ 記述できます。

# %% [markdown]
# %pwd

# %%
# %time
# Out:
# Wall time: 0 ns

# %%
# %pwd
# Out:
# 'C:\\Users\\buby405\\Desktop\\PG\\python\\jupyter\\notebooks'

# %%
# !ipconfig
# Out:
# Windows IP 構成
#
#
# Wireless LAN adapter ローカル エリア接続* 1:
#
#    メディアの状態. . . . . . . . . . . .: メディアは接続されていません
#    接続固有の DNS サフィックス . . . . .:
#
# Wireless LAN adapter ローカル エリア接続* 12:
#
#    メディアの状態. . . . . . . . . . . .: メディアは接続されていません
#    接続固有の DNS サフィックス . . . . .:
#
# Wireless LAN adapter Wi-Fi:
#
#    接続固有の DNS サフィックス . . . . .: wi2.ne.jp
#    リンクローカル IPv6 アドレス. . . . .: fe80::14d4:8f2:ea81:8676%7
#    IPv4 アドレス . . . . . . . . . . . .: 10.36.194.28
#    サブネット マスク . . . . . . . . . .: 255.255.224.0
#    デフォルト ゲートウェイ . . . . . . .: 10.36.192.1
#
# イーサネット アダプター Bluetooth ネットワーク接続:
#
#    メディアの状態. . . . . . . . . . . .: メディアは接続されていません
#    接続固有の DNS サフィックス . . . . .:

# %%
# %time sum(range(10000))
# Out:
# Wall time: 0 ns
# 49995000

# %%
# %timeit sum(range(10000))
# Out:
# 482 µs ± 19.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit -n 2000 -r 5 sum(range(10000))
# Out:
# 478 µs ± 11 µs per loop (mean ± std. dev. of 5 runs, 2000 loops each)

# %%
# %%timeit -n 1000 -r 3

for i in range(1000):
    i*2
# Out:
# 130 µs ± 5.42 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
# %history -l 10
# Out:
# %pwd
# !ipconfig
# %time sum(range(10000))
# %timeit sum(range(10000))
# %timeit -n 2000 -r 5 sum(range(10000))
# %% timeit -n 1000 -r 3
#
# for i in range(1000):
#     i*2
# %timeit -n 1000 -r 3
#
# for i in range(1000):
#     i*2
# %%timeit -n 1000 -r 3
#
# for i in range(1000):
#     i*2
# %history -l 3
# %history -l 4

# %%
# %ls
# Out:
#  ドライブ C のボリューム ラベルは Windows です
#  ボリューム シリアル番号は 60A9-FAF5 です
#
#  C:\Users\buby405\Desktop\PG\python\jupyter\notebooks のディレクトリ
#
# 2020/07/03  17:43    <DIR>          .
# 2020/07/03  17:43    <DIR>          ..
# 2020/07/03  17:23    <DIR>          .ipynb_checkpoints
# 2020/06/28  22:13             2,157 check_Matplotlib_Config.ipynb
# 2020/06/28  18:52            41,048 matplotlibrc
# 2020/07/03  17:43             5,389 Untitled.ipynb
# 2020/06/28  19:39            11,738 useJPFont.ipynb
#                4 個のファイル              60,332 バイト
#                3 個のディレクトリ  128,360,685,568 バイトの空き領域

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,20,0.2)
y = np.sin(x)

# %%
flg = plt.figure()
ax = flg.add_subplot(111)

ax.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="784.0000598144577">
